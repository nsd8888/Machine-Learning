# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
dl=df[['diagnosis','radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean']]
sns.heatmap(dl.corr(),annot=True)
plt.show()

# %%
dl.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430

# %%
dl=dl.drop(dl[['smoothness_mean']],axis=1)
sns.pairplot(dl,hue='diagnosis')

# %%
#since the smoothness mean features has overlapped dataset. therefore we can not classify it.

# %%
sns.pairplot(dl,diag_kind='kde')

# %%
sns.boxplot(dl['radius_mean'])
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='radius_mean'>

# %%
sns.boxplot(dl['perimeter_mean'])
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='perimeter_mean'>

# %%
sns.boxplot(dl['area_mean'])
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area_mean'>

# %%
sns.boxplot(dl['compactness_mean'])
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='compactness_mean'>

# %%
sns.boxplot(dl['concavity_mean'])
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='concavity_mean'>

# %%
sns.boxplot(dl['concave points_mean'])
# Out:
# c:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='concave points_mean'>

# %%
def outlier_detection(data):
  Q1 = data.quantile(0.25)
  Q3 = data.quantile(0.75)
  IQR = Q3 - Q1
  upper_end = Q3 + 1.5 * IQR
  lower_end = Q1 - 1.5 * IQR 
  outlier = data[(data > upper_end) | (data < lower_end)]
  return outlier

# %%
outlier_detection(dl['radius_mean'])
# Out:
# 82     25.22
# 108    22.27
# 122    24.25
# 164    23.27
# 180    27.22
# 202    23.29
# 212    28.11
# 236    23.21
# 339    23.51
# 352    25.73
# 369    22.01
# 461    27.42
# 503    23.09
# 521    24.63
# Name: radius_mean, dtype: float64

# %%
outlier_detection(dl['perimeter_mean'])
# Out:
# 82     171.5
# 108    152.8
# 122    166.2
# 164    152.1
# 180    182.1
# 202    158.9
# 212    188.5
# 236    153.5
# 339    155.1
# 352    174.2
# 461    186.9
# 503    152.1
# 521    165.5
# Name: perimeter_mean, dtype: float64

# %%
outlier_detection(dl['area_mean'])
# Out:
# 23     1404.0
# 82     1878.0
# 108    1509.0
# 122    1761.0
# 164    1686.0
# 180    2250.0
# 202    1685.0
# 212    2499.0
# 236    1670.0
# 250    1364.0
# 265    1419.0
# 272    1491.0
# 339    1747.0
# 352    2010.0
# 368    1546.0
# 369    1482.0
# 372    1386.0
# 373    1335.0
# 393    1407.0
# 449    1384.0
# 461    2501.0
# 503    1682.0
# 521    1841.0
# 563    1347.0
# 564    1479.0
# Name: area_mean, dtype: float64

# %%
outlier_detection(dl['compactness_mean'])
# Out:
# 0      0.2776
# 3      0.2839
# 9      0.2396
# 12     0.2458
# 14     0.2293
# 78     0.3454
# 82     0.2665
# 108    0.2768
# 122    0.2867
# 181    0.2832
# 190    0.2413
# 258    0.3114
# 351    0.2364
# 352    0.2363
# 400    0.2576
# 567    0.2770
# Name: compactness_mean, dtype: float64

# %%
outlier_detection(dl['texture_mean'])
# Out:
# 219    32.47
# 232    33.81
# 239    39.28
# 259    33.56
# 265    31.12
# 455    30.72
# 562    30.62
# Name: texture_mean, dtype: float64

# %%
outlier_detection(dl['concavity_mean'])
# Out:
# 0      0.3001
# 68     0.3130
# 78     0.3754
# 82     0.3339
# 108    0.4264
# 112    0.3003
# 122    0.4268
# 152    0.4108
# 180    0.2871
# 202    0.3523
# 212    0.3201
# 258    0.3176
# 351    0.2914
# 352    0.3368
# 400    0.3189
# 461    0.3635
# 563    0.3174
# 567    0.3514
# Name: concavity_mean, dtype: float64

# %%
outlier_detection(dl['concave points_mean'])
# Out:
# 78     0.1604
# 82     0.1845
# 108    0.1823
# 122    0.2012
# 180    0.1878
# 202    0.1620
# 212    0.1595
# 352    0.1913
# 393    0.1562
# 461    0.1689
# Name: concave points_mean, dtype: float64

# %%
outlier_detection(dl['area_mean'])
# Out:
# 23     1404.0
# 82     1878.0
# 108    1509.0
# 122    1761.0
# 164    1686.0
# 180    2250.0
# 202    1685.0
# 212    2499.0
# 236    1670.0
# 250    1364.0
# 265    1419.0
# 272    1491.0
# 339    1747.0
# 352    2010.0
# 368    1546.0
# 369    1482.0
# 372    1386.0
# 373    1335.0
# 393    1407.0
# 449    1384.0
# 461    2501.0
# 503    1682.0
# 521    1841.0
# 563    1347.0
# 564    1479.0
# Name: area_mean, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
dl['diagnosis']=lb.fit_transform(dl['diagnosis'])

# %%
sns.heatmap(dl.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dl,diag_kind='kde')

# %%
dl.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    compactness_mean  concavity_mean  concave points_mean
# 0           0.27760          0.3001              0.14710
# 1           0.07864          0.0869              0.07017
# 2           0.15990          0.1974              0.12790
# 3           0.28390          0.2414              0.10520
# 4           0.13280          0.1980              0.10430

# %%
from sklearn.model_selection import train_test_split
X=dl.drop(dl[['diagnosis']],axis=1)
y=dl['diagnosis']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# %%
sm=LogisticRegression(random_state=0)

res=sm.fit(X_train,y_train)
# Out:
# c:\python\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
y_pred=res.predict(X_test)

# %%
acc=confusion_matrix(y_pred,y_test)
acc
# Out:
# array([[98, 11],
#        [10, 52]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
bcc=accuracy_score(y_pred,y_test)

# %%
import statsmodels.api as sl

# %%
X_train_sl = sl.add_constant(X_train)
# Out:
# c:\python\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
lr = sl.OLS(y_train, X_train_sl).fit()
lr.params
# Out:
# const                 -1.670449
# radius_mean            0.572880
# texture_mean           0.021032
# perimeter_mean        -0.070206
# area_mean             -0.000774
# compactness_mean       1.416465
# concavity_mean         0.606502
# concave points_mean    6.234085
# dtype: float64

# %%
from sklearn.metrics import confusion_matrix

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              diagnosis   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                     122.7
# Date:                Sun, 08 Aug 2021   Prob (F-statistic):           1.69e-94
# Time:                        09:23:52   Log-Likelihood:                -44.238
# No. Observations:                 398   AIC:                             104.5
# Df Residuals:                     390   BIC:                             136.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -1.6704      0.201     -8.318      0.000      -2.065      -1.276
# ...
